# %%
# importing all the required libraries
import os
import numpy as np
import pandas as pd
import librosa
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from xgboost import XGBClassifier

# %%
def extract_features(file_name):
    try:
        audio_data, sample_rate = librosa.load(file_name, sr=None, res_type='kaiser_fast')

        # Extract MFCCs
        mfccs = librosa.feature.mfcc(y=audio_data, sr=sample_rate, n_mfcc=13)
        mfccs_mean = np.mean(mfccs.T, axis=0)

        # Extract Chroma features
        chroma = librosa.feature.chroma_stft(y=audio_data, sr=sample_rate)
        chroma_mean = np.mean(chroma.T, axis=0)

        # Extract Mel Spectrogram
        mel = librosa.feature.melspectrogram(y=audio_data, sr=sample_rate)
        mel_mean = np.mean(mel.T, axis=0)

        # Extract Tempo (Rhythm)
        onset_env = librosa.onset.onset_strength(y=audio_data, sr=sample_rate)
        tempo = librosa.feature.rhythm.tempo(onset_envelope=onset_env, sr=sample_rate)[0]

        # Combine all features into a single array
        features = np.hstack([mfccs_mean, chroma_mean, mel_mean, tempo])
        return features
    
    except Exception as e:
        print(f"Error encountered while parsing file: {file_name}, Error: {e}")
        return None

# %%
data_dir = '.\Data'
genres = os.listdir(data_dir)

features_list = []
labels_list = []

for genre in genres:
    genre_dir = os.path.join(data_dir, genre)
    if os.path.isdir(genre_dir):
        for file in os.listdir(genre_dir):
            if file.endswith('.wav'):
                file_path = os.path.join(genre_dir, file)
                features = extract_features(file_path)
                if features is not None:
                    features_list.append(features)
                    labels_list.append(genre)

# Convert to pandas DataFrame
features_df = pd.DataFrame(features_list)
labels_df = pd.DataFrame(labels_list, columns=['label'])
dataset = pd.concat([features_df, labels_df], axis=1, ignore_index=True)

# %%
# Column names for MFCCs, Chroma, Mel, and Tempo
mfcc_names = [f'mfcc_{i+1}' for i in range(13)]
chroma_names = [f'chroma_{i+1}' for i in range(12)]
mel_names = [f'mel_{i+1}' for i in range(128)]
tempo_name = ['tempo']


# Combine all column names
feature_column_names = mfcc_names + chroma_names + mel_names + tempo_name + ['Genre']

# Assign column names to the features DataFrame
dataset.columns = feature_column_names

# %%
X = dataset.drop(columns=['Genre'])
y = dataset['Genre']

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)


# Encode labels to numerical values
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y = le.fit_transform(y)

# Split data
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
# Initialize the XGBoost classifier
xgb = XGBClassifier(colsample_bytree= 0.61,   # L1 regularization term
    learning_rate= 0.0625, max_depth= 6, min_child_weight= 1, n_estimators= 270, subsample= 0.71, eval_metrics='mlogloss')

# Train the model
xgb.fit(X_train, y_train, eval_set=[(X_test, y_test)],# Validation set
    verbose=True)

# Predict on test data
y_pred = xgb.predict(X_test)

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy * 100:.2f}%')
# Out:
# [0]	validation_0-mlogloss:2.21610
# [1]	validation_0-mlogloss:2.13741
# c:\Users\Swarupa\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\core.py:158: UserWarning: [18:13:10] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "eval_metrics" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [2]	validation_0-mlogloss:2.06090
# [3]	validation_0-mlogloss:2.00573
# [4]	validation_0-mlogloss:1.95997
# [5]	validation_0-mlogloss:1.91477
# [6]	validation_0-mlogloss:1.86646
# [7]	validation_0-mlogloss:1.82232
# [8]	validation_0-mlogloss:1.78554
# [9]	validation_0-mlogloss:1.75083
# [10]	validation_0-mlogloss:1.71925
# [11]	validation_0-mlogloss:1.68337
# [12]	validation_0-mlogloss:1.65709
# [13]	validation_0-mlogloss:1.63237
# [14]	validation_0-mlogloss:1.60412
# [15]	validation_0-mlogloss:1.58073
# [16]	validation_0-mlogloss:1.55832
# [17]	validation_0-mlogloss:1.53539
# [18]	validation_0-mlogloss:1.51510
# [19]	validation_0-mlogloss:1.49368
# [20]	validation_0-mlogloss:1.47849
# [21]	validation_0-mlogloss:1.46263
# [22]	validation_0-mlogloss:1.44535
# [23]	validation_0-mlogloss:1.42871
# [24]	validation_0-mlogloss:1.41225
# [25]	validation_0-mlogloss:1.39739
# [26]	validation_0-mlogloss:1.38012
# [27]	validation_0-mlogloss:1.36370
# [28]	validation_0-mlogloss:1.34842
# [29]	validation_0-mlogloss:1.33498
# [30]	validation_0-mlogloss:1.32183
# [31]	validation_0-mlogloss:1.31039
# [32]	validation_0-mlogloss:1.29612
# [33]	validation_0-mlogloss:1.28276
# [34]	validation_0-mlogloss:1.27422
# [35]	validation_0-mlogloss:1.26722
# [36]	validation_0-mlogloss:1.25791
# [37]	validation_0-mlogloss:1.24787
# [38]	validation_0-mlogloss:1.23966
# [39]	validation_0-mlogloss:1.22874
# [40]	validation_0-mlogloss:1.22138
# [41]	validation_0-mlogloss:1.21219
# [42]	validation_0-mlogloss:1.20505
# [43]	validation_0-mlogloss:1.19573
# [44]	validation_0-mlogloss:1.18914
# [45]	validation_0-mlogloss:1.17813
# [46]	validation_0-mlogloss:1.17242
# [47]	validation_0-mlogloss:1.16714
# [48]	validation_0-mlogloss:1.16076
# [49]	validation_0-mlogloss:1.15331
# [50]	validation_0-mlogloss:1.14751
# [51]	validation_0-mlogloss:1.14001
# [52]	validation_0-mlogloss:1.13644
# [53]	validation_0-mlogloss:1.13085
# [54]	validation_0-mlogloss:1.12602
# [55]	validation_0-mlogloss:1.12052
# [56]	validation_0-mlogloss:1.11483
# [57]	validation_0-mlogloss:1.10933
# [58]	validation_0-mlogloss:1.10347
# [59]	validation_0-mlogloss:1.09801
# [60]	validation_0-mlogloss:1.09333
# [61]	validation_0-mlogloss:1.08832
# [62]	validation_0-mlogloss:1.08462
# [63]	validation_0-mlogloss:1.08063
# [64]	validation_0-mlogloss:1.07722
# [65]	validation_0-mlogloss:1.07419
# [66]	validation_0-mlogloss:1.07005
# [67]	validation_0-mlogloss:1.06710
# [68]	validation_0-mlogloss:1.06292
# [69]	validation_0-mlogloss:1.05886
# [70]	validation_0-mlogloss:1.05463
# [71]	validation_0-mlogloss:1.05270
# [72]	validation_0-mlogloss:1.04859
# [73]	validation_0-mlogloss:1.04620
# [74]	validation_0-mlogloss:1.04470
# [75]	validation_0-mlogloss:1.04215
# [76]	validation_0-mlogloss:1.03958
# [77]	validation_0-mlogloss:1.03889
# [78]	validation_0-mlogloss:1.03662
# [79]	validation_0-mlogloss:1.03382
# [80]	validation_0-mlogloss:1.03111
# [81]	validation_0-mlogloss:1.02912
# [82]	validation_0-mlogloss:1.02650
# [83]	validation_0-mlogloss:1.02490
# [84]	validation_0-mlogloss:1.02334
# [85]	validation_0-mlogloss:1.02194
# [86]	validation_0-mlogloss:1.01929
# [87]	validation_0-mlogloss:1.01723
# [88]	validation_0-mlogloss:1.01519
# [89]	validation_0-mlogloss:1.01313
# [90]	validation_0-mlogloss:1.01059
# [91]	validation_0-mlogloss:1.00838
# [92]	validation_0-mlogloss:1.00623
# [93]	validation_0-mlogloss:1.00481
# [94]	validation_0-mlogloss:1.00398
# [95]	validation_0-mlogloss:1.00177
# [96]	validation_0-mlogloss:0.99985
# [97]	validation_0-mlogloss:0.99832
# [98]	validation_0-mlogloss:0.99652
# [99]	validation_0-mlogloss:0.99576
# [100]	validation_0-mlogloss:0.99503
# [101]	validation_0-mlogloss:0.99441
# [102]	validation_0-mlogloss:0.99448
# [103]	validation_0-mlogloss:0.99344
# [104]	validation_0-mlogloss:0.99235
# [105]	validation_0-mlogloss:0.99028
# [106]	validation_0-mlogloss:0.99036
# [107]	validation_0-mlogloss:0.98844
# [108]	validation_0-mlogloss:0.98790
# [109]	validation_0-mlogloss:0.98723
# [110]	validation_0-mlogloss:0.98491
# [111]	validation_0-mlogloss:0.98409
# [112]	validation_0-mlogloss:0.98437
# [113]	validation_0-mlogloss:0.98456
# [114]	validation_0-mlogloss:0.98318
# [115]	validation_0-mlogloss:0.98405
# [116]	validation_0-mlogloss:0.98429
# [117]	validation_0-mlogloss:0.98315
# [118]	validation_0-mlogloss:0.98294
# [119]	validation_0-mlogloss:0.98177
# [120]	validation_0-mlogloss:0.98091
# [121]	validation_0-mlogloss:0.98040
# [122]	validation_0-mlogloss:0.97902
# [123]	validation_0-mlogloss:0.97783
# [124]	validation_0-mlogloss:0.97792
# [125]	validation_0-mlogloss:0.97808
# [126]	validation_0-mlogloss:0.97659
# [127]	validation_0-mlogloss:0.97552
# [128]	validation_0-mlogloss:0.97442
# [129]	validation_0-mlogloss:0.97399
# [130]	validation_0-mlogloss:0.97361
# [131]	validation_0-mlogloss:0.97369
# [132]	validation_0-mlogloss:0.97355
# [133]	validation_0-mlogloss:0.97343
# [134]	validation_0-mlogloss:0.97269
# [135]	validation_0-mlogloss:0.97234
# [136]	validation_0-mlogloss:0.97086
# [137]	validation_0-mlogloss:0.97066
# [138]	validation_0-mlogloss:0.96984
# [139]	validation_0-mlogloss:0.97067
# [140]	validation_0-mlogloss:0.96960
# [141]	validation_0-mlogloss:0.96916
# [142]	validation_0-mlogloss:0.96951
# [143]	validation_0-mlogloss:0.96990
# [144]	validation_0-mlogloss:0.97014
# [145]	validation_0-mlogloss:0.97009
# [146]	validation_0-mlogloss:0.96924
# [147]	validation_0-mlogloss:0.96882
# [148]	validation_0-mlogloss:0.96888
# [149]	validation_0-mlogloss:0.96841
# [150]	validation_0-mlogloss:0.96776
# [151]	validation_0-mlogloss:0.96797
# [152]	validation_0-mlogloss:0.96695
# [153]	validation_0-mlogloss:0.96540
# [154]	validation_0-mlogloss:0.96459
# [155]	validation_0-mlogloss:0.96492
# [156]	validation_0-mlogloss:0.96533
# [157]	validation_0-mlogloss:0.96543
# [158]	validation_0-mlogloss:0.96527
# [159]	validation_0-mlogloss:0.96457
# [160]	validation_0-mlogloss:0.96377
# [161]	validation_0-mlogloss:0.96283
# [162]	validation_0-mlogloss:0.96239
# [163]	validation_0-mlogloss:0.96288
# [164]	validation_0-mlogloss:0.96292
# [165]	validation_0-mlogloss:0.96325
# [166]	validation_0-mlogloss:0.96334
# [167]	validation_0-mlogloss:0.96335
# [168]	validation_0-mlogloss:0.96196
# [169]	validation_0-mlogloss:0.96077
# [170]	validation_0-mlogloss:0.96095
# [171]	validation_0-mlogloss:0.96220
# [172]	validation_0-mlogloss:0.96209
# [173]	validation_0-mlogloss:0.96084
# [174]	validation_0-mlogloss:0.96065
# [175]	validation_0-mlogloss:0.96120
# [176]	validation_0-mlogloss:0.96082
# [177]	validation_0-mlogloss:0.96119
# [178]	validation_0-mlogloss:0.96138
# [179]	validation_0-mlogloss:0.96122
# [180]	validation_0-mlogloss:0.96201
# [181]	validation_0-mlogloss:0.96110
# [182]	validation_0-mlogloss:0.96009
# [183]	validation_0-mlogloss:0.95949
# [184]	validation_0-mlogloss:0.95950
# [185]	validation_0-mlogloss:0.95989
# [186]	validation_0-mlogloss:0.95979
# [187]	validation_0-mlogloss:0.96007
# [188]	validation_0-mlogloss:0.96136
# [189]	validation_0-mlogloss:0.96127
# [190]	validation_0-mlogloss:0.96141
# [191]	validation_0-mlogloss:0.96127
# [192]	validation_0-mlogloss:0.96136
# [193]	validation_0-mlogloss:0.96222
# [194]	validation_0-mlogloss:0.96146
# [195]	validation_0-mlogloss:0.96201
# [196]	validation_0-mlogloss:0.96151
# [197]	validation_0-mlogloss:0.96134
# [198]	validation_0-mlogloss:0.96137
# [199]	validation_0-mlogloss:0.96151
# [200]	validation_0-mlogloss:0.96186
# [201]	validation_0-mlogloss:0.96143
# [202]	validation_0-mlogloss:0.96074
# [203]	validation_0-mlogloss:0.96121
# [204]	validation_0-mlogloss:0.96128
# [205]	validation_0-mlogloss:0.96131
# [206]	validation_0-mlogloss:0.96227
# [207]	validation_0-mlogloss:0.96266
# [208]	validation_0-mlogloss:0.96266
# [209]	validation_0-mlogloss:0.96323
# [210]	validation_0-mlogloss:0.96264
# [211]	validation_0-mlogloss:0.96285
# [212]	validation_0-mlogloss:0.96251
# [213]	validation_0-mlogloss:0.96193
# [214]	validation_0-mlogloss:0.96121
# [215]	validation_0-mlogloss:0.96149
# [216]	validation_0-mlogloss:0.96129
# [217]	validation_0-mlogloss:0.96115
# [218]	validation_0-mlogloss:0.96162
# [219]	validation_0-mlogloss:0.96181
# [220]	validation_0-mlogloss:0.96150
# [221]	validation_0-mlogloss:0.96177
# [222]	validation_0-mlogloss:0.96096
# [223]	validation_0-mlogloss:0.96077
# [224]	validation_0-mlogloss:0.96075
# [225]	validation_0-mlogloss:0.96068
# [226]	validation_0-mlogloss:0.96027
# [227]	validation_0-mlogloss:0.96037
# [228]	validation_0-mlogloss:0.96059
# [229]	validation_0-mlogloss:0.96027
# [230]	validation_0-mlogloss:0.96034
# [231]	validation_0-mlogloss:0.96046
# [232]	validation_0-mlogloss:0.96097
# [233]	validation_0-mlogloss:0.96128
# [234]	validation_0-mlogloss:0.96139
# [235]	validation_0-mlogloss:0.96121
# [236]	validation_0-mlogloss:0.96131
# [237]	validation_0-mlogloss:0.96161
# [238]	validation_0-mlogloss:0.96214
# [239]	validation_0-mlogloss:0.96251
# [240]	validation_0-mlogloss:0.96240
# [241]	validation_0-mlogloss:0.96271
# [242]	validation_0-mlogloss:0.96321
# [243]	validation_0-mlogloss:0.96352
# [244]	validation_0-mlogloss:0.96336
# [245]	validation_0-mlogloss:0.96277
# [246]	validation_0-mlogloss:0.96207
# [247]	validation_0-mlogloss:0.96176
# [248]	validation_0-mlogloss:0.96202
# [249]	validation_0-mlogloss:0.96220
# [250]	validation_0-mlogloss:0.96259
# [251]	validation_0-mlogloss:0.96230
# [252]	validation_0-mlogloss:0.96225
# [253]	validation_0-mlogloss:0.96266
# [254]	validation_0-mlogloss:0.96290
# [255]	validation_0-mlogloss:0.96322
# [256]	validation_0-mlogloss:0.96252
# [257]	validation_0-mlogloss:0.96244
# [258]	validation_0-mlogloss:0.96247
# [259]	validation_0-mlogloss:0.96269
# [260]	validation_0-mlogloss:0.96318
# [261]	validation_0-mlogloss:0.96276
# [262]	validation_0-mlogloss:0.96303
# [263]	validation_0-mlogloss:0.96330
# [264]	validation_0-mlogloss:0.96340
# [265]	validation_0-mlogloss:0.96401
# [266]	validation_0-mlogloss:0.96434
# [267]	validation_0-mlogloss:0.96397
# [268]	validation_0-mlogloss:0.96363
# [269]	validation_0-mlogloss:0.96364
# Accuracy: 69.00%

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(classification_report(y_test, y_pred, target_names=le.classes_))

# Confusion matrix
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_iris
from sklearn.ensemble import RandomForestClassifier

# Load dataset
cm = confusion_matrix(y_test, y_pred)

# Plot the confusion matrix
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
            xticklabels=['Blues','Classical','Country','Disco','HipHop','Jazz','Metal','Pop','Reggae','Rock'],
            yticklabels=['Blues','Classical','Country','Disco','HipHop','Jazz','Metal','Pop','Reggae','Rock'])
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#        Blues       0.54      0.70      0.61        20
#    Classical       0.87      1.00      0.93        13
#      Country       0.78      0.52      0.62        27
#        Disco       0.65      0.62      0.63        21
#       HipHop       0.56      0.60      0.58        15
#         Jazz       0.83      0.86      0.84        22
#        Metal       0.85      0.92      0.88        25
#          Pop       0.67      0.77      0.71        13
#       Reggae       0.71      0.52      0.60        23
#         Rock       0.48      0.52      0.50        21
#
#     accuracy                           0.69       200
#    macro avg       0.69      0.70      0.69       200
# weighted avg       0.70      0.69      0.69       200

# %%
# List of genres
genres = ['Blues', 'Classical', 'Country', 'Disco', 'HipHop', 
          'Jazz', 'Metal', 'Pop', 'Reggae', 'Rock']

# Assuming xgb is your trained model and X_test is your test data
prediction = xgb.predict(X_test[[34]])

# Get the genre name from the prediction
predicted_genre = genres[prediction[0]]

print(predicted_genre)
xgb.save_model("model.pkl")
# Out:
# Disco
# c:\Users\Swarupa\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\core.py:158: UserWarning: [18:32:00] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\c_api\c_api.cc:1374: Saving model in the UBJSON format as default.  You can use file extension: `json`, `ubj` or `deprecated` to choose between formats.
#   warnings.warn(smsg, UserWarning)
